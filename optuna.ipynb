# %%
import numpy as np 
import pandas as pd
import optuna as opt
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
data = pd.read_csv(url, header=None, names=columns)
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
cols_with_missing_values = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
data[cols_with_missing_values] = data[cols_with_missing_values].replace(0, np.nan)

data.fillna(data.mean(), inplace=True)

print(data.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
x = data.drop('Outcome', axis=1)
y = data['Outcome']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

print(f"Training set shape: {x_train.shape}, Test set shape: {x_test.shape}")
# Out:
# Training set shape: (614, 8), Test set shape: (154, 8)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 50, 200)
    max_depth = trial.suggest_int('max_depth', 3, 20)

    model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        random_state=42
    )

    scores = cross_val_score(model, x_train, y_train, cv=3, scoring='accuracy')
    return scores.mean()

# %%
study = opt.create_study(direction='maximize', sampler=opt.samplers.TPESampler())
study.optimize(objective, n_trials=50)
# Out:
# [I 2025-11-20 15:26:22,255] A new study created in memory with name: no-name-4f99e176-1a2a-4f31-8cc3-18e29c3b5c25
# [I 2025-11-20 15:26:22,530] Trial 0 finished with value: 0.7556910569105691 and parameters: {'n_estimators': 118, 'max_depth': 4}. Best is trial 0 with value: 0.7556910569105691.
# [I 2025-11-20 15:26:22,986] Trial 1 finished with value: 0.780121154152718 and parameters: {'n_estimators': 190, 'max_depth': 12}. Best is trial 1 with value: 0.780121154152718.
# [I 2025-11-20 15:26:23,343] Trial 2 finished with value: 0.780113183484776 and parameters: {'n_estimators': 150, 'max_depth': 13}. Best is trial 1 with value: 0.780121154152718.
# [I 2025-11-20 15:26:23,525] Trial 3 finished with value: 0.7703570859238004 and parameters: {'n_estimators': 79, 'max_depth': 7}. Best is trial 1 with value: 0.780121154152718.
# [I 2025-11-20 15:26:23,766] Trial 4 finished with value: 0.7540650406504065 and parameters: {'n_estimators': 115, 'max_depth': 4}. Best is trial 1 with value: 0.780121154152718.
# [I 2025-11-20 15:26:24,096] Trial 5 finished with value: 0.7719591901801371 and parameters: {'n_estimators': 152, 'max_depth': 5}. Best is trial 1 with value: 0.780121154152718.
# [I 2025-11-20 15:26:24,454] Trial 6 finished with value: 0.7670891120675912 and parameters: {'n_estimators': 158, 'max_depth': 7}. Best is trial 1 with value: 0.780121154152718.
# [I 2025-11-20 15:26:24,688] Trial 7 finished with value: 0.7736250597800095 and parameters: {'n_estimators': 96, 'max_depth': 11}. Best is trial 1 with value: 0.780121154152718.
# [I 2025-11-20 15:26:25,073] Trial 8 finished with value: 0.7686991869918699 and parameters: {'n_estimators': 161, 'max_depth': 20}. Best is trial 1 with value: 0.780121154152718.
# [I 2025-11-20 15:26:25,278] Trial 9 finished with value: 0.7670891120675912 and parameters: {'n_estimators': 87, 'max_depth': 8}. Best is trial 1 with value: 0.780121154152718.
# [I 2025-11-20 15:26:25,787] Trial 10 finished with value: 0.7768611509644509 and parameters: {'n_estimators': 200, 'max_depth': 15}. Best is trial 1 with value: 0.780121154152718.
# [I 2025-11-20 15:26:26,274] Trial 11 finished with value: 0.7768611509644509 and parameters: {'n_estimators': 200, 'max_depth': 14}. Best is trial 1 with value: 0.780121154152718.
# [I 2025-11-20 15:26:26,684] Trial 12 finished with value: 0.780121154152718 and parameters: {'n_estimators': 173, 'max_depth': 12}. Best is trial 1 with value: 0.780121154152718.
# [I 2025-11-20 15:26:26,818] Trial 13 finished with value: 0.7768452096285668 and parameters: {'n_estimators': 52, 'max_depth': 17}. Best is trial 1 with value: 0.780121154152718.
# [I 2025-11-20 15:26:27,233] Trial 14 finished with value: 0.776837238960625 and parameters: {'n_estimators': 178, 'max_depth': 10}. Best is trial 1 with value: 0.780121154152718.
# [I 2025-11-20 15:26:27,657] Trial 15 finished with value: 0.7638211382113821 and parameters: {'n_estimators': 179, 'max_depth': 17}. Best is trial 1 with value: 0.780121154152718.
# [I 2025-11-20 15:26:28,078] Trial 16 finished with value: 0.776837238960625 and parameters: {'n_estimators': 178, 'max_depth': 10}. Best is trial 1 with value: 0.780121154152718.
# [I 2025-11-20 15:26:28,390] Trial 17 finished with value: 0.7785031085604973 and parameters: {'n_estimators': 131, 'max_depth': 12}. Best is trial 1 with value: 0.780121154152718.
# [I 2025-11-20 15:26:28,822] Trial 18 finished with value: 0.7768531802965088 and parameters: {'n_estimators': 183, 'max_depth': 16}. Best is trial 1 with value: 0.780121154152718.
# [I 2025-11-20 15:26:29,152] Trial 19 finished with value: 0.7768611509644509 and parameters: {'n_estimators': 137, 'max_depth': 20}. Best is trial 1 with value: 0.780121154152718.
# [I 2025-11-20 15:26:29,539] Trial 20 finished with value: 0.7735931771082417 and parameters: {'n_estimators': 167, 'max_depth': 9}. Best is trial 1 with value: 0.780121154152718.
# [I 2025-11-20 15:26:29,886] Trial 21 finished with value: 0.7850071736011478 and parameters: {'n_estimators': 145, 'max_depth': 13}. Best is trial 21 with value: 0.7850071736011478.
# [I 2025-11-20 15:26:30,218] Trial 22 finished with value: 0.7817471704128806 and parameters: {'n_estimators': 138, 'max_depth': 13}. Best is trial 21 with value: 0.7850071736011478.
# [I 2025-11-20 15:26:30,472] Trial 23 finished with value: 0.78012912482066 and parameters: {'n_estimators': 105, 'max_depth': 13}. Best is trial 21 with value: 0.7850071736011478.
# [I 2025-11-20 15:26:30,736] Trial 24 finished with value: 0.7833891280089271 and parameters: {'n_estimators': 110, 'max_depth': 14}. Best is trial 21 with value: 0.7850071736011478.
# [I 2025-11-20 15:26:31,076] Trial 25 finished with value: 0.7752271640363463 and parameters: {'n_estimators': 143, 'max_depth': 18}. Best is trial 21 with value: 0.7850071736011478.
# [I 2025-11-20 15:26:31,373] Trial 26 finished with value: 0.7784871672246134 and parameters: {'n_estimators': 124, 'max_depth': 15}. Best is trial 21 with value: 0.7850071736011478.
# [I 2025-11-20 15:26:31,555] Trial 27 finished with value: 0.771975131516021 and parameters: {'n_estimators': 74, 'max_depth': 14}. Best is trial 21 with value: 0.7850071736011478.
# [I 2025-11-20 15:26:31,892] Trial 28 finished with value: 0.780113183484776 and parameters: {'n_estimators': 140, 'max_depth': 14}. Best is trial 21 with value: 0.7850071736011478.
# [I 2025-11-20 15:26:32,153] Trial 29 finished with value: 0.7752510760401722 and parameters: {'n_estimators': 108, 'max_depth': 11}. Best is trial 21 with value: 0.7850071736011478.
# [I 2025-11-20 15:26:32,456] Trial 30 finished with value: 0.78012912482066 and parameters: {'n_estimators': 125, 'max_depth': 18}. Best is trial 21 with value: 0.7850071736011478.
# [I 2025-11-20 15:26:32,711] Trial 31 finished with value: 0.78012912482066 and parameters: {'n_estimators': 105, 'max_depth': 13}. Best is trial 21 with value: 0.7850071736011478.
# [I 2025-11-20 15:26:32,988] Trial 32 finished with value: 0.7850071736011478 and parameters: {'n_estimators': 114, 'max_depth': 13}. Best is trial 21 with value: 0.7850071736011478.
# [I 2025-11-20 15:26:33,271] Trial 33 finished with value: 0.780121154152718 and parameters: {'n_estimators': 116, 'max_depth': 15}. Best is trial 21 with value: 0.7850071736011478.
# [I 2025-11-20 15:26:33,596] Trial 34 finished with value: 0.7833811573409851 and parameters: {'n_estimators': 132, 'max_depth': 13}. Best is trial 21 with value: 0.7850071736011478.
# [I 2025-11-20 15:26:33,816] Trial 35 finished with value: 0.7784951378925554 and parameters: {'n_estimators': 92, 'max_depth': 10}. Best is trial 21 with value: 0.7850071736011478.
# [I 2025-11-20 15:26:34,170] Trial 36 finished with value: 0.7784632552207875 and parameters: {'n_estimators': 149, 'max_depth': 16}. Best is trial 21 with value: 0.7850071736011478.
# [I 2025-11-20 15:26:34,478] Trial 37 finished with value: 0.7703491152558585 and parameters: {'n_estimators': 130, 'max_depth': 11}. Best is trial 21 with value: 0.7850071736011478.
# [I 2025-11-20 15:26:34,747] Trial 38 finished with value: 0.7752510760401722 and parameters: {'n_estimators': 112, 'max_depth': 12}. Best is trial 21 with value: 0.7850071736011478.
# [I 2025-11-20 15:26:34,944] Trial 39 finished with value: 0.7475370636059302 and parameters: {'n_estimators': 99, 'max_depth': 3}. Best is trial 21 with value: 0.7850071736011478.
# [I 2025-11-20 15:26:35,239] Trial 40 finished with value: 0.7850231149370317 and parameters: {'n_estimators': 122, 'max_depth': 14}. Best is trial 40 with value: 0.7850231149370317.
# [I 2025-11-20 15:26:35,541] Trial 41 finished with value: 0.7833970986768691 and parameters: {'n_estimators': 117, 'max_depth': 14}. Best is trial 40 with value: 0.7850231149370317.
# [I 2025-11-20 15:26:35,837] Trial 42 finished with value: 0.7850231149370317 and parameters: {'n_estimators': 122, 'max_depth': 14}. Best is trial 40 with value: 0.7850231149370317.
# [I 2025-11-20 15:26:36,124] Trial 43 finished with value: 0.780121154152718 and parameters: {'n_estimators': 118, 'max_depth': 16}. Best is trial 40 with value: 0.7850231149370317.
# [I 2025-11-20 15:26:36,420] Trial 44 finished with value: 0.7752351347042882 and parameters: {'n_estimators': 123, 'max_depth': 15}. Best is trial 40 with value: 0.7850231149370317.
# [I 2025-11-20 15:26:36,779] Trial 45 finished with value: 0.7785031085604973 and parameters: {'n_estimators': 150, 'max_depth': 12}. Best is trial 40 with value: 0.7850231149370317.
# [I 2025-11-20 15:26:36,997] Trial 46 finished with value: 0.7736091184441256 and parameters: {'n_estimators': 87, 'max_depth': 14}. Best is trial 40 with value: 0.7850231149370317.
# [I 2025-11-20 15:26:37,288] Trial 47 finished with value: 0.78012912482066 and parameters: {'n_estimators': 119, 'max_depth': 17}. Best is trial 40 with value: 0.7850231149370317.
# [I 2025-11-20 15:26:37,640] Trial 48 finished with value: 0.7703252032520326 and parameters: {'n_estimators': 161, 'max_depth': 6}. Best is trial 40 with value: 0.7850231149370317.
# [I 2025-11-20 15:26:37,888] Trial 49 finished with value: 0.7752271640363463 and parameters: {'n_estimators': 98, 'max_depth': 13}. Best is trial 40 with value: 0.7850231149370317.
